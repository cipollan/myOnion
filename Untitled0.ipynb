# %% [markdown]
# <a href="https://colab.research.google.com/github/cipollan/myOnion/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file_path1 = "/content/sample_data/PRODUZ-IIMS0_CC_TRASF_ATTIV-dq-ctrl-G-19-05-2023-07-35-13.txt"  # Replace with the actual file path
file_path2 = "/content/sample_data/PRODUZ-IIMS0_CC_TRASF_ATTIV-dq-ctrl-G-19-05-2023-07-35-13.txt"  # Replace with the actual file path

try:
    with open(file_path1, 'r') as file:
        contents = file.read()
        print(contents)  # Display the contents of the file
        
except FileNotFoundError:
    print("File not found.")
except IOError:
    print("Error reading the file.")
# Out:
# +--- CONTROLLO TECNICO FINE APP = IIMS0_CC_TRASF_ATTIV - Giorni: 2 ---+
# 'CTRL-FUNZ-PROC-001-id_processo is null'
# 'CTRL-FUNZ-PROC-002-ID_SUPERPRATICA is null'
# 'CTRL-FUNZ-PROC-003-APPLICAZIONE is null'
# 'CTRL-FUNZ-PROC-004-ABI_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-005-FILIALE_CLIENTE is null o non valido
# 'CTRL-FUNZ-PROC-006-NSG_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-007-NSG_CONTRATTUALE is null o non valido'
# 'CTRL-FUNZ-PROC-008-BT_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-009-CF_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-011-COGNOME_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-012-IS_PROSPECT is null o non valido'
# 'CTRL-FUNZ-PROC-013-ID_PROSPECT is null o non valido'
# 'CTRL-FUNZ-PROC-014-TIPOLOGIA_OFFERTA NON VALIDA'
# 'CTRL-FUNZ-PROC-015-TIPO_FIRMA NON VALIDA'
# 'CTRL-FUNZ-PROC-016-TIPO_PROPOSTA NON VALIDA'
# 'CTRL-FUNZ-PROC-017-CAMBIO_OFFERTA NON VALIDA'
# 'CTRL-FUNZ-PROC-018-CANCELLATO NON VALIDA'
# ...

# %% [markdown]
# # Nuova sezione

# %%
file_path = "/content/sample_data/PRODUZ-IIMS0_CC_TRASF_ATTIV-dq-ctrl-G-19-05-2023-07-35-13.txt"  # Replace with the actual file path

try:
    with open(file_path, 'r') as file:
        contents = file.read()
        print(contents)  # Display the contents of the file
except FileNotFoundError:
    print("File not found.")
except IOError:
    print("Error reading the file.")
# Out:
# +--- CONTROLLO TECNICO FINE APP = IIMS0_CC_TRASF_ATTIV - Giorni: 2 ---+
# 'CTRL-FUNZ-PROC-001-id_processo is null'
# 'CTRL-FUNZ-PROC-002-ID_SUPERPRATICA is null'
# 'CTRL-FUNZ-PROC-003-APPLICAZIONE is null'
# 'CTRL-FUNZ-PROC-004-ABI_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-005-FILIALE_CLIENTE is null o non valido
# 'CTRL-FUNZ-PROC-006-NSG_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-007-NSG_CONTRATTUALE is null o non valido'
# 'CTRL-FUNZ-PROC-008-BT_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-009-CF_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-011-COGNOME_CLIENTE is null o non valido'
# 'CTRL-FUNZ-PROC-012-IS_PROSPECT is null o non valido'
# 'CTRL-FUNZ-PROC-013-ID_PROSPECT is null o non valido'
# 'CTRL-FUNZ-PROC-014-TIPOLOGIA_OFFERTA NON VALIDA'
# 'CTRL-FUNZ-PROC-015-TIPO_FIRMA NON VALIDA'
# 'CTRL-FUNZ-PROC-016-TIPO_PROPOSTA NON VALIDA'
# 'CTRL-FUNZ-PROC-017-CAMBIO_OFFERTA NON VALIDA'
# 'CTRL-FUNZ-PROC-018-CANCELLATO NON VALIDA'
# ...

# %% [markdown]
# # Nuova sezione

# %% [markdown]
# # Nuova sezione
